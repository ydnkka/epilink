# %%
from evaluate import evaluate_scenario

# %%
tree = "../../data/processed/scovmod/scovmod_tree.gml"

fixed = {
    "latent_shape":3.38,
    "symptomatic_rate":0.37,
    "symptomatic_shape":1.0,
    "transmission_rate_ratio":2.29,
    "fraction_sampled":1.0,
    "genome_length":29903,            # Used for sub/site/year -> sub/genome/day
    "synthetic_genome_length":5000,   # Length of sequences to actually simulate
    "num_simulations":10000,
    "target":("ad(0)", "ca(0,0)"),
    "maximum_depth":0
}

generation = {**fixed,
    "incubation_shape":5.807,
    "incubation_scale":0.948,
    "testing_delay_shape":1.0,
    "testing_delay_scale":1.0,
    "substitution_rate":0.001,
    "relaxation":0.33,
}

inference = {**fixed,
    "incubation_shape":5.807,
    "incubation_scale":0.948,
    "testing_delay_shape":1.0,
    "testing_delay_scale":1.0,
    "substitution_rate":0.001,
    "relaxation":0.33,
}

# %%
result, classifiers = evaluate_scenario(
    tree,
    "test",
    generation,
    inference,
    return_classifier=True,
    n_restarts=1,
)

# %%
result.models
# Out:
# {'EDD': ModelResult(ap=0.2995788664843665, ap_loss=None, best_f1=0.5571607871402452, f1_loss=None, mean_stability=0.8748080343060446, std_stability=0.0796402124228899),
#  'EDS': ModelResult(ap=0.09046246152476779, ap_loss=None, best_f1=0.47543793636995224, f1_loss=None, mean_stability=0.8550472953865714, std_stability=0.1012590992626756),
#  'ESD': ModelResult(ap=0.4657766754190462, ap_loss=None, best_f1=0.6040154762966174, f1_loss=None, mean_stability=0.8485870874372331, std_stability=0.07434900425910522),
#  'ESS': ModelResult(ap=0.18668481123542924, ap_loss=None, best_f1=0.5310377542895565, f1_loss=None, mean_stability=0.83317012582935, std_stability=0.07852943863833312),
#  'LD': ModelResult(ap=0.5679221606023711, ap_loss=None, best_f1=0.6864045063102662, f1_loss=None, mean_stability=0.8971282450343934, std_stability=0.045243954162725995),
#  'LS': ModelResult(ap=0.2753555941443073, ap_loss=None, best_f1=0.5710324527864307, f1_loss=None, mean_stability=0.9273854724651424, std_stability=0.09386093799497873)}

# %%
# from experiments import run_experiment
# import yaml
#
# with open("../../config.yaml", "r") as f:
#     config = yaml.safe_load(f)
#
# df = run_experiment(config)
# print(df.head())
